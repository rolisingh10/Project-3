# %%
# importing the dependencies
import pandas as pd
import numpy
import json
from json import loads, dumps

# %% [markdown]
# ##Cancer Rates Data##

# %%
# Making the dataframe to inspect the data
df_cancer = pd.read_csv("Source_Data/Countytable.csv")
df_cancer.head()
# Out:
#                Cancer header         County County population  Note   Rate  \
# 0  All cancer types combined          Mower            39,807   NaN  410.7
# 1  All cancer types combined           Todd            24,494   NaN  414.3
# 2  All cancer types combined       Fillmore            20,949   NaN  416.5
# 3  All cancer types combined  Lac qui Parle             6,719   NaN  422.4
# 4  All cancer types combined    Koochiching            12,515   NaN  422.7
#
#                  Cancer type       Sex
# 0  All cancer types combined  Everyone
# 1  All cancer types combined  Everyone
# 2  All cancer types combined  Everyone
# 3  All cancer types combined  Everyone
# 4  All cancer types combined  Everyone

# %%
# getting rid of some columns and renaming some columns
df_cancer.drop(["Cancer header", "Note","Cancer type","Sex"], axis = 1,inplace = True)
df_cancer.head()
# Out:
#           County County population   Rate
# 0          Mower            39,807  410.7
# 1           Todd            24,494  414.3
# 2       Fillmore            20,949  416.5
# 3  Lac qui Parle             6,719  422.4
# 4    Koochiching            12,515  422.7

# %%
df_cancer = df_cancer.rename(columns = {"Rate": "cancer_rate_per_100k","County population": "county_population","County":"county"})
df_cancer.head()
# Out:
#           county county_population  cancer_rate_per_100k
# 0          Mower            39,807                 410.7
# 1           Todd            24,494                 414.3
# 2       Fillmore            20,949                 416.5
# 3  Lac qui Parle             6,719                 422.4
# 4    Koochiching            12,515                 422.7

# %%
# sort by county name 
df_cancer.sort_values(by = "county",inplace = True)
df_cancer.head()
# Out:
#       county county_population  cancer_rate_per_100k
# 26    Aitkin            15,834                 449.5
# 64     Anoka           350,253                 486.5
# 69    Becker            34,011                 491.9
# 70  Beltrami            46,403                 492.3
# 7     Benton            40,129                 428.1

# %%
# setting the index
df_cancer.reset_index(drop= True, inplace = True)
df_cancer.head()
# Out:
#      county county_population  cancer_rate_per_100k
# 0    Aitkin            15,834                 449.5
# 1     Anoka           350,253                 486.5
# 2    Becker            34,011                 491.9
# 3  Beltrami            46,403                 492.3
# 4    Benton            40,129                 428.1

# %%
# checking for null values
df_cancer.isnull().sum()
# Out:
# county                  0
# county_population       0
# cancer_rate_per_100k    0
# dtype: int64

# %%
# checking the duplicated values
df_cancer.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 83    False
# 84    False
# 85    False
# 86    False
# 87    False
# Length: 88, dtype: bool

# %%
#checking the data types
df_cancer.dtypes
# Out:
# county                   object
# county_population        object
# cancer_rate_per_100k    float64
# dtype: object

# %%
# change the datatype of county population to integer
df_cancer['county_population'] = df_cancer['county_population'].str.replace(',', '').astype(float)
#df_cancer[['County population']].apply(pd.to_numeric) 
#df_cancer.dtypes
df_cancer.head()
# Out:
#      county  county_population  cancer_rate_per_100k
# 0    Aitkin            15834.0                 449.5
# 1     Anoka           350253.0                 486.5
# 2    Becker            34011.0                 491.9
# 3  Beltrami            46403.0                 492.3
# 4    Benton            40129.0                 428.1

# %%
df_cancer.dtypes
# Out:
# county                   object
# county_population       float64
# cancer_rate_per_100k    float64
# dtype: object

# %% [markdown]
# ## Health Outcomes Data ##

# %%
#reading the healthoutcome excel file 
df_healthoutcome = pd.read_excel("Source_Data/HealthOutcomeAndFactors.xlsx",header = 1)
df_healthoutcome.head()
# Out:
#       FIPS      State    County   Z-Score  Rank  Z-Score.1  Rank.1
# 0      NaN        NaN       NaN       NaN   NaN        NaN     NaN
# 1  27001.0  Minnesota    Aitkin  0.431450  69.0   0.761015    82.0
# 2  27003.0  Minnesota     Anoka -0.426424  23.0  -0.413081    17.0
# 3  27005.0  Minnesota    Becker  0.472333  71.0   0.169356    63.0
# 4  27007.0  Minnesota  Beltrami  1.717782  86.0   0.763052    83.0

# %%
#Renaming the columns
df_healthoutcome.rename( columns = {"Z-Score":"hlt_outcome_z", 
                                    "Rank":"hlt_outcome_rank","Z-Score.1":"hlt_factor_z",
                                    "Rank.1":"hlt_factor_rank","County": "county"}, inplace = True)
df_healthoutcome.head()
# Out:
#       FIPS      State    county  hlt_outcome_z  hlt_outcome_rank  \
# 0      NaN        NaN       NaN            NaN               NaN
# 1  27001.0  Minnesota    Aitkin       0.431450              69.0
# 2  27003.0  Minnesota     Anoka      -0.426424              23.0
# 3  27005.0  Minnesota    Becker       0.472333              71.0
# 4  27007.0  Minnesota  Beltrami       1.717782              86.0
#
#    hlt_factor_z  hlt_factor_rank
# 0           NaN              NaN
# 1      0.761015             82.0
# 2     -0.413081             17.0
# 3      0.169356             63.0
# 4      0.763052             83.0

# %%
df_healthoutcome.drop(index = 0,inplace = True)
df_healthoutcome.head()
# Out:
#       FIPS      State    county  hlt_outcome_z  hlt_outcome_rank  \
# 1  27001.0  Minnesota    Aitkin       0.431450              69.0
# 2  27003.0  Minnesota     Anoka      -0.426424              23.0
# 3  27005.0  Minnesota    Becker       0.472333              71.0
# 4  27007.0  Minnesota  Beltrami       1.717782              86.0
# 5  27009.0  Minnesota    Benton      -0.022054              47.0
#
#    hlt_factor_z  hlt_factor_rank
# 1      0.761015             82.0
# 2     -0.413081             17.0
# 3      0.169356             63.0
# 4      0.763052             83.0
# 5      0.114975             59.0

# %%
# resetting the index
df_healthoutcome.reset_index( drop = True, inplace = True)
df_healthoutcome.head()
# Out:
#       FIPS      State    county  hlt_outcome_z  hlt_outcome_rank  \
# 0  27001.0  Minnesota    Aitkin       0.431450              69.0
# 1  27003.0  Minnesota     Anoka      -0.426424              23.0
# 2  27005.0  Minnesota    Becker       0.472333              71.0
# 3  27007.0  Minnesota  Beltrami       1.717782              86.0
# 4  27009.0  Minnesota    Benton      -0.022054              47.0
#
#    hlt_factor_z  hlt_factor_rank
# 0      0.761015             82.0
# 1     -0.413081             17.0
# 2      0.169356             63.0
# 3      0.763052             83.0
# 4      0.114975             59.0

# %%
# dropping column 
df_healthoutcome.drop( columns = ["State"], inplace = True)
df_healthoutcome.head()
# Out:
#       FIPS    county  hlt_outcome_z  hlt_outcome_rank  hlt_factor_z  \
# 0  27001.0    Aitkin       0.431450              69.0      0.761015
# 1  27003.0     Anoka      -0.426424              23.0     -0.413081
# 2  27005.0    Becker       0.472333              71.0      0.169356
# 3  27007.0  Beltrami       1.717782              86.0      0.763052
# 4  27009.0    Benton      -0.022054              47.0      0.114975
#
#    hlt_factor_rank
# 0             82.0
# 1             17.0
# 2             63.0
# 3             83.0
# 4             59.0

# %% [markdown]
# ## Asthma Data ##

# %%
#reading the asthma data
df_asthma = pd.read_csv("Source_Data/MN-asthma-county.csv")
df_asthma.head()
# Out:
#           __Outcome     __Year  _County Age-adjusted rate per 10,000  \
# 0  Hospitalizations  2018-2020   Winona                          0.5
# 1  Hospitalizations  2018-2020     Todd                          0.6
# 2  Hospitalizations  2018-2020   Wright                          1.1
# 3  Hospitalizations  2018-2020  Wabasha                          1.1
# 4  Hospitalizations  2018-2020   Waseca                          1.1
#
#                                     Note Count of cases
# 0  Unstable rate due to small population              9
# 1  Unstable rate due to small population              7
# 2                                    NaN             45
# 3  Unstable rate due to small population              7
# 4  Unstable rate due to small population              7

# %%
# Getting the column names
df_asthma.columns
# Out:
# Index(['__Outcome', '__Year', '_County', 'Age-adjusted rate per 10,000',
#        'Note', 'Count of cases'],
#       dtype='object')

# %%
 # dropping some columns
df_asthma.drop(['__Outcome', '__Year','Note'], axis = 1,inplace = True)
df_asthma.head()
# Out:
#    _County Age-adjusted rate per 10,000 Count of cases
# 0   Winona                          0.5              9
# 1     Todd                          0.6              7
# 2   Wright                          1.1             45
# 3  Wabasha                          1.1              7
# 4   Waseca                          1.1              7

# %%
# Renaming the columns
df_asthma.rename(columns = {"_County": "county","Age-adjusted rate per 10,000":"asthma_rate_per_100k","Count of cases":
                           "count_of_cases"}, inplace = True)
df_asthma.head()
# Out:
#     county asthma_rate_per_100k count_of_cases
# 0   Winona                  0.5              9
# 1     Todd                  0.6              7
# 2   Wright                  1.1             45
# 3  Wabasha                  1.1              7
# 4   Waseca                  1.1              7

# %%
# sorting data by county names
df_asthma.sort_values(by = "county", inplace = True)
df_asthma.head()
# Out:
#       county asthma_rate_per_100k count_of_cases
# 22    Aitkin                    2              9
# 42     Anoka                  2.6            262
# 46    Becker                  2.7             26
# 59  Beltrami                  3.7             55
# 52    Benton                  3.2             37

# %%
# Resetting the index
df_asthma.reset_index(drop= True, inplace = True)
df_asthma
# Out:
#              county asthma_rate_per_100k count_of_cases
# 0            Aitkin                    2              9
# 1             Anoka                  2.6            262
# 2            Becker                  2.7             26
# 3          Beltrami                  3.7             55
# 4            Benton                  3.2             37
# ..              ...                  ...            ...
# 83         Watonwan                    *              *
# 84           Wilkin                    *              *
# 85           Winona                  0.5              9
# 86           Wright                  1.1             45
# 87  Yellow Medicine                  3.1              8
#
# [88 rows x 3 columns]

# %%
# checking the length of dataframe
len(df_asthma)
# Out:
# 88

# %%
#Checking for null values
df_asthma.isnull().sum()
# Out:
# county                  0
# asthma_rate_per_100k    0
# count_of_cases          0
# dtype: int64

# %%
# checking for data types 
df_asthma.dtypes
# Out:
# county                  object
# asthma_rate_per_100k    object
# count_of_cases          object
# dtype: object

# %%
df_asthma['asthma_rate_per_100k'] = pd.to_numeric(df_asthma['asthma_rate_per_100k']
                                                                           ,errors='coerce')
df_asthma.dtypes
# Out:
# county                   object
# asthma_rate_per_100k    float64
# count_of_cases           object
# dtype: object

# %%
df_asthma['count_of_cases'] = pd.to_numeric(df_asthma['count_of_cases'], errors='coerce')
                                                                           
df_asthma.dtypes
# Out:
# county                   object
# asthma_rate_per_100k    float64
# count_of_cases          float64
# dtype: object

# %%
df_asthma.head()
# Out:
#      county  asthma_rate_per_100k  count_of_cases
# 0    Aitkin                   2.0             9.0
# 1     Anoka                   2.6           262.0
# 2    Becker                   2.7            26.0
# 3  Beltrami                   3.7            55.0
# 4    Benton                   3.2            37.0

# %% [markdown]
# ## EPA FRS Sites Data ##

# %%
# Read in CSV file to create EPA FRS dataframe
df_epa_frs = pd.read_csv("Source_Data/STATE_SINGLE_MN.csv")
# Out:
# /var/folders/_9/80bxm26n3b5300q7n7g729_c0000gn/T/ipykernel_39508/3862334911.py:2: DtypeWarning: Columns (5,7,13,14,15,16,21,27,29,30,34,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_epa_frs = pd.read_csv("Source_Data/STATE_SINGLE_MN.csv")

# %%
# inspect dataframe 
df_epa_frs.head()
# Out:
#                       FRS_FACILITY_DETAIL_REPORT_URL   REGISTRY_ID  \
# 0  https://ofmpub.epa.gov/frs_public2/fii_query_d...  110055452380
# 1  https://ofmpub.epa.gov/frs_public2/fii_query_d...  110055527835
# 2  https://ofmpub.epa.gov/frs_public2/fii_query_d...  110069113113
# 3  https://ofmpub.epa.gov/frs_public2/fii_query_d...  110068363425
# 4  https://ofmpub.epa.gov/frs_public2/fii_query_d...  110068290904
#
#                      PRIMARY_NAME          LOCATION_ADDRESS  \
# 0           SHERWIN-WILLIAMS 3296     10690 BALTIMORE ST NE
# 1                PARKER AUTO MALL              6771 MAIN ST
# 2  150TH STREET - AASTAD TOWNSHIP  SEE LOCATION DESCRIPTION
# 3       AASTAD TOWNSHIP DUMP SITE  SEE LOCATION DESCRIPTION
# 4                GARY T LIEN FARM           12701 220TH AVE
#
#   SUPPLEMENTAL_LOCATION              CITY_NAME COUNTY_NAME FIPS_CODE  \
# 0                   NaN  10690 BALTIMORE ST NE       ANOKA     27003
# 1                   NaN           6771 MAIN ST     CHISAGO     27025
# 2                   NaN        AASTAD TOWNSHIP  OTTER TAIL     27111
# 3                   NaN        AASTAD TOWNSHIP  OTTER TAIL     27111
# 4                   NaN        AASTAD TOWNSHIP  OTTER TAIL     27111
#
#   STATE_CODE STATE_NAME  ... SIC_CODES               SIC_CODE_DESCRIPTIONS  \
# 0         MN  MINNESOTA  ...      5231  PAINT, GLASS, AND WALLPAPER STORES
# 1         MN  MINNESOTA  ...       NaN                                 NaN
# 2         MN  MINNESOTA  ...       NaN                                 NaN
# 3         MN  MINNESOTA  ...       NaN                                 NaN
# 4         MN  MINNESOTA  ...       NaN                                 NaN
#
#   LATITUDE83 LONGITUDE83     CONVEYOR                   COLLECT_DESC  \
# 0   45.16277   -93.23254  FRS-GEOCODE  ADDRESS MATCHING-HOUSE NUMBER
# 1   45.51152   -92.97108  FRS-GEOCODE  ADDRESS MATCHING-HOUSE NUMBER
# 2        NaN         NaN          NaN                            NaN
# 3        NaN         NaN          NaN                            NaN
# 4   46.14703   -96.02937  FRS-GEOCODE  ADDRESS MATCHING-HOUSE NUMBER
#
#   ACCURACY_VALUE                   REF_POINT_DESC  HDATUM_DESC  SOURCE_DESC
# 0           30.0  CENTER OF A FACILITY OR STATION        NAD83          NaN
# 1           30.0  CENTER OF A FACILITY OR STATION        NAD83          NaN
# 2            NaN                              NaN        NAD83          NaN
# 3            NaN                              NaN        NAD83          NaN
# 4           30.0  CENTER OF A FACILITY OR STATION        NAD83          NaN
#
# [5 rows x 39 columns]

# %%
# inspect columns
df_epa_frs.columns
# Out:
# Index(['FRS_FACILITY_DETAIL_REPORT_URL', 'REGISTRY_ID', 'PRIMARY_NAME',
#        'LOCATION_ADDRESS', 'SUPPLEMENTAL_LOCATION', 'CITY_NAME', 'COUNTY_NAME',
#        'FIPS_CODE', 'STATE_CODE', 'STATE_NAME', 'COUNTRY_NAME', 'POSTAL_CODE',
#        'FEDERAL_FACILITY_CODE', 'FEDERAL_AGENCY_NAME', 'TRIBAL_LAND_CODE',
#        'TRIBAL_LAND_NAME', 'CONGRESSIONAL_DIST_NUM', 'CENSUS_BLOCK_CODE',
#        'HUC_CODE', 'EPA_REGION_CODE', 'SITE_TYPE_NAME', 'LOCATION_DESCRIPTION',
#        'CREATE_DATE', 'UPDATE_DATE', 'US_MEXICO_BORDER_IND', 'PGM_SYS_ACRNMS',
#        'INTEREST_TYPES', 'NAICS_CODES', 'NAICS_CODE_DESCRIPTIONS', 'SIC_CODES',
#        'SIC_CODE_DESCRIPTIONS', 'LATITUDE83', 'LONGITUDE83', 'CONVEYOR',
#        'COLLECT_DESC', 'ACCURACY_VALUE', 'REF_POINT_DESC', 'HDATUM_DESC',
#        'SOURCE_DESC'],
#       dtype='object')

# %%
# create new dataframe by dropping unneccessary columns
df_epa_frs_clean = df_epa_frs[['REGISTRY_ID', 'PRIMARY_NAME', 'LOCATION_ADDRESS', 'COUNTY_NAME','SITE_TYPE_NAME', 'INTEREST_TYPES', 'LATITUDE83', 'LONGITUDE83']]

# rename columns for readability
df_epa_frs_clean.rename(columns = {'LATITUDE83': 'LATITUDE', 'LONGITUDE83': 'LONGITUDE', 'PRIMARY_NAME': 'SITE PRIMARY NAME', 'LOCATION_ADDRESS': 'SITE_ADDRESS'}, inplace = True)
# Out:
# /var/folders/_9/80bxm26n3b5300q7n7g729_c0000gn/T/ipykernel_39508/4280381693.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_epa_frs_clean.rename(columns = {'LATITUDE83': 'LATITUDE', 'LONGITUDE83': 'LONGITUDE', 'PRIMARY_NAME': 'SITE PRIMARY NAME', 'LOCATION_ADDRESS': 'SITE_ADDRESS'}, inplace = True)

# %%
#drop rows with null values in coordinate, interest types, location address, or site types columns
df_epa_frs_clean = df_epa_frs_clean.dropna(axis=0, subset=['LATITUDE'])
df_epa_frs_clean = df_epa_frs_clean.dropna(axis=0, subset=['LONGITUDE'])

# %%
# drop rows where interest type is "state master" only
df_epa_frs_clean = df_epa_frs_clean[df_epa_frs_clean.INTEREST_TYPES != "STATE MASTER"]

# %%
# create list of search terms for interest types to try and narrow down to relevant sites
search_term_list = ['RELEASE ASSESSMENT','AIR EMISSION INVENTORY', 'AIR MAJOR', 'AIR MINOR', 'AIR SYNTHETIC MINOR', 'ELECTRIC GENERATOR', 'ELECTRIC POWER GENERAT', 'ETHANOL FACILITY', 'GASOLINE', 'GREENHOUSE GAS', 'ANIMAL', 'LIVESTOCK', 'TRI REPORTER', 'TSCA SUBMITTER', 'EPCRA', 'FRP', 'SPCC', 'MINERAL EXPLORATION', 'CATHODE RAY', 'CESQG', 'CORRECTIVE ACTION', 'HAZARDOUS WASTE', 'INCINERATOR', 'INFECTIOUS WASTE', 'LQG', 'SQG', 'TSD', 'UIC', 'USED OIL', 'COMPLIANCE', 'ENFORCEMENT', 'PESTICIDE', 'RAD NPL', 'RAD WIPP', 'RAD NESHAPS', 'RADIOACTIVE', 'CLEANUP', 'REMEDIATION', 'REMEDIAL', 'BROWNFIELDS', 'SEDIMENTS', 'SUPERFUND', 'E-WASTE', 'INDUSTRIAL SITES', 'MATERIAL RECYCLING', 'MINE', 'MINING', 'OIL CONTROL', 'REFUSE DISPOSAL', 'SCRAP TIRE MANAGEMENT', 'SEWAGE SLUDGE', 'SOLID WASTE', 'LEAKING STORAGE TANK','UNDERGROUND STORAGE TANK', 'BIOSOLIDS', 'NPDES MAJOR', 'NPDES-MINOR', 'NPDES NON-MAJOR' 'NPDES UNPERMITTED', 'OIL AND GAS', 'MULTI-PERMITTED SITE']

# filter dataframe by search term list within the Interest_Types field
final_epa_frs_clean = df_epa_frs_clean[df_epa_frs_clean['INTEREST_TYPES'].str.contains('|'.join(search_term_list), na=False)]

# %%
# modified list of search terms for a smaller, more precise dataset focused on pollution
modified_search_term_list = ['TRI REPORTER', 'BROWNFIELDS PROPERTY', 'PESTICIDE PRODUCER', 'LQG', 'AIR MAJOR', 'TSCA SUBMITTER', 'HAZARDOUS AIR POLLUTANT MAJOR', 'GREENHOUSE GAS REPORTER', 'SUPERFUND', 'GASOLINE AND DIESEL PRODUCERS', 'ICIS-NPDES MAJOR', 'LEAKING UNDERGROUND STORAGE TANK', 'OIL BASED', 'GAS BASED', 'TSD', 'COAL BASED']

# filter dataframe by search term list within the Interest_Types field
modified_final_epa_frs_clean = df_epa_frs_clean[df_epa_frs_clean['INTEREST_TYPES'].str.contains('|'.join(modified_search_term_list), na=False)]

# filter out certain strings
modified_final_epa_frs_clean[modified_final_epa_frs_clean["INTEREST_TYPES"].str.contains('VSQG')==False]
modified_final_epa_frs_clean[modified_final_epa_frs_clean["INTEREST_TYPES"].str.contains('SQG')==False]
# Out:
#          REGISTRY_ID            SITE PRIMARY NAME        SITE_ADDRESS  \
# 191     110040710905     13869 FORMER GAS STATION    402 W THORPE AVE
# 203     110017862954          ADA FEED & SEED INC  117 W MAIN ST SOUT
# 282     110071164025      SIMPLOT AB RETAIL, INC.       999 W MAIN ST
# 293     110038254509             TRIANGLE AG, LLC          202 W MAIN
# 327     110008059028   LAND O'LAKES FARMLAND FEED      13 COMMERCE ST
# ...              ...                          ...                 ...
# 211069  110070698829  ST. OLAF STANDBY GENERATORS                 NaN
# 213002  110070699470           UNITED HEALTH CARE                 NaN
# 213037  110070699471     UNIV MINNESOTA CHP PLANT                 NaN
# 214228  110070699426               WEST FAIRBAULT                 NaN
# 214310  110070699429      WESTSIDE ENERGY STATION                 NaN
#
#           COUNTY_NAME SITE_TYPE_NAME                           INTEREST_TYPES  \
# 191            NORMAN     STATIONARY  LEAKING UNDERGROUND STORAGE TANK - ARRA
# 203            NORMAN     STATIONARY  COMPLIANCE ACTIVITY, PESTICIDE PRODUCER
# 282     NORMAN COUNTY     STATIONARY                       PESTICIDE PRODUCER
# 293            NORMAN     STATIONARY                       PESTICIDE PRODUCER
# 327             MOWER     STATIONARY                             TRI REPORTER
# ...               ...            ...                                      ...
# 211069           RICE            NaN     ELECTRIC POWER GENERATOR (OIL BASED)
# 213002       HENNEPIN            NaN     ELECTRIC POWER GENERATOR (OIL BASED)
# 213037       HENNEPIN            NaN     ELECTRIC POWER GENERATOR (GAS BASED)
# 214228           RICE            NaN     ELECTRIC POWER GENERATOR (GAS BASED)
# 214310        OLMSTED            NaN     ELECTRIC POWER GENERATOR (GAS BASED)
#
#          LATITUDE  LONGITUDE
# 191     47.296260 -96.520978
# 203     47.296295 -96.515827
# 282     47.310540 -96.519700
# 293     47.297522 -96.516176
# 327     43.564190 -92.713809
# ...           ...        ...
# 211069  44.461111 -93.180833
# 213002  44.984444 -93.360833
# 213037  44.978611 -93.240833
# 214228  44.269722 -93.290556
# 214310  44.039023 -92.551866
#
# [2999 rows x 8 columns]

# %%
# inspect final dataframe
final_epa_frs_clean.tail(10)
# Out:
#          REGISTRY_ID              SITE PRIMARY NAME SITE_ADDRESS COUNTY_NAME  \
# 214725  110070699431         WINONA COUNTY WIND LLC          NaN      WINONA
# 214733  110070699432                   WINONA SOLAR          NaN      WINONA
# 214804  110070934927            WOLLAN GARDEN SOLAR          NaN        POPE
# 214826  110070934928                 WOODBURY SOLAR          NaN  WASHINGTON
# 214916  110070699433             WRIGHT CUDDYER CSG          NaN      WRIGHT
# 214920  110070698748           WRIGHT KIRBY 1-5 CSG          NaN      WRIGHT
# 214925  110070698738             WRIGHTSUN CSG, LLC          NaN      WRIGHT
# 214949  110070698739             WYOMING 2 CSG, LLC          NaN     CHISAGO
# 215080  110070698740  ZUMBRO COMMUNITY SOLAR GARDEN          NaN     GOODHUE
# 215083  110070934929            ZUMBRO SOLAR GARDEN          NaN       DODGE
#
#        SITE_TYPE_NAME                          INTEREST_TYPES   LATITUDE  \
# 214725            NaN   ELECTRIC POWER GENERATOR (WIND BASED)  44.112500
# 214733            NaN  ELECTRIC POWER GENERATOR (SOLAR BASED)  44.124097
# 214804            NaN  ELECTRIC POWER GENERATOR (SOLAR BASED)  45.637121
# 214826            NaN  ELECTRIC POWER GENERATOR (SOLAR BASED)  44.881944
# 214916            NaN  ELECTRIC POWER GENERATOR (SOLAR BASED)  45.183100
# 214920            NaN  ELECTRIC POWER GENERATOR (SOLAR BASED)  45.259000
# 214925            NaN  ELECTRIC POWER GENERATOR (SOLAR BASED)  45.216430
# 214949            NaN  ELECTRIC POWER GENERATOR (SOLAR BASED)  45.350000
# 215080            NaN  ELECTRIC POWER GENERATOR (SOLAR BASED)  44.319478
# 215083            NaN  ELECTRIC POWER GENERATOR (SOLAR BASED)  44.046030
#
#         LONGITUDE
# 214725 -91.924722
# 214733 -91.900997
# 214804 -95.530903
# 214826 -92.967500
# 214916 -93.734100
# 214920 -93.791000
# 214925 -93.718376
# 214949 -92.950000
# 215080 -92.670339
# 215083 -92.759990

# %%
modified_final_epa_frs_clean.tail(10)
# Out:
#          REGISTRY_ID              SITE PRIMARY NAME SITE_ADDRESS COUNTY_NAME  \
# 205458  110070698885               MINNESOTA VALLEY          NaN    CHIPPEWA
# 207094  110070699138        OWATONNA ENERGY STATION          NaN      STEELE
# 207915  110070699148  POET BIOREFINING LAKE CRYSTAL          NaN  BLUE EARTH
# 209981  110070699372           SHAKOPEE ENERGY PARK          NaN       SCOTT
# 210501  110070698825          SOUTHEAST STEAM PLANT          NaN    HENNEPIN
# 211069  110070698829    ST. OLAF STANDBY GENERATORS          NaN        RICE
# 213002  110070699470             UNITED HEALTH CARE          NaN    HENNEPIN
# 213037  110070699471       UNIV MINNESOTA CHP PLANT          NaN    HENNEPIN
# 214228  110070699426                 WEST FAIRBAULT          NaN        RICE
# 214310  110070699429        WESTSIDE ENERGY STATION          NaN     OLMSTED
#
#        SITE_TYPE_NAME                        INTEREST_TYPES   LATITUDE  \
# 205458            NaN  ELECTRIC POWER GENERATOR (GAS BASED)  44.802778
# 207094            NaN  ELECTRIC POWER GENERATOR (GAS BASED)  44.085225
# 207915            NaN  ELECTRIC POWER GENERATOR (GAS BASED)  44.093333
# 209981            NaN  ELECTRIC POWER GENERATOR (GAS BASED)  44.783611
# 210501            NaN  ELECTRIC POWER GENERATOR (GAS BASED)  44.980833
# 211069            NaN  ELECTRIC POWER GENERATOR (OIL BASED)  44.461111
# 213002            NaN  ELECTRIC POWER GENERATOR (OIL BASED)  44.984444
# 213037            NaN  ELECTRIC POWER GENERATOR (GAS BASED)  44.978611
# 214228            NaN  ELECTRIC POWER GENERATOR (GAS BASED)  44.269722
# 214310            NaN  ELECTRIC POWER GENERATOR (GAS BASED)  44.039023
#
#         LONGITUDE
# 205458 -95.526944
# 207094 -93.262714
# 207915 -94.276667
# 209981 -93.481111
# 210501 -93.249722
# 211069 -93.180833
# 213002 -93.360833
# 213037 -93.240833
# 214228 -93.290556
# 214310 -92.551866

# %% [markdown]
# ## JSONIFY dataframes for ingestion into DB ##

# %%
# saving the data in an output file as json format
df_cancer.to_json('Cleaned_Data/cancer(2015-2019).json', orient='records')

# %%
# Saving the file in json format
df_healthoutcome.to_json('Cleaned_Data/healthoutcome(2023).json', orient='records')

# %%
# saving the file in json form
df_asthma.to_json('Cleaned_Data/asthma(2018-2020).json', orient='records')

# %%
# convert EPA DFs to json
final_epa_frs_clean.to_json('Cleaned_Data/epa_frs_data.json', orient='records')
modified_final_epa_frs_clean.to_json('Cleaned_Data/modified_final_epa_frs_clean.json', orient='records')
